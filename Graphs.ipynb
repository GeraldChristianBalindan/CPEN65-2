# %% [markdown]
# <a href="https://colab.research.google.com/github/GeraldChristianBalindan/CPEN65-2/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![323105725_596604048942245_4217824101058976183_n.png](data:image/png;base64,...)

# %%
G9 = (V9,E9)
V9 = {1,2,3,4,5,6}
E9 = {(1,2),(2,1),(1,5),(6,1),(5,6),(5,4),(2,4),(6,3)}

Indegree of:
node 1: v = (2,6) 
node 2: v = (2)
node 3: v = (6)
node 4: v = (2,5)
node 5: v = (1)
node 6: v = (5)

Outdegree of:
node 1: v = (2,5) 
node 2: v = (1,4)
node 3: v = ()
node 4: v = ()
node 5: v = (4,6)
node 6: v = (1,3)

Adjacent to:
node 1: v = (6,2) 
node 2: v = (2)
node 3: v = (6)
node 4: v = (5,2)
node 5: v = (1)
node 6: v = (5)

Adjacent from:
node 1: v = (5,2) 
node 2: v = (4,1)
node 3: v = ()
node 4: v = ()
node 5: v = (4,6)
node 6: v = (1,3)

Edges incident to:
node 1: v = {(1,2),(2,1),(1,5),(6,1)} 
node 2: v = {(2,1),(1,2),(2,4)}
node 3: v = {(6,3)}
node 4: v = {(2,4),(5,4)}
node 5: v = {(1,5),(5,6),(5,4)}
node 6: v = {(5,6),(6,1),(6,3)}

Simple Paths:

1-2
1-2-4
2-1
2-1-5
2-1-5-4
5-4
5-6
5-6-1
5-6-1-2
5-6-1-2-4
6-3
6-1
6-1-2
6-1-2-4

Simple Cycles:

1-2-1
2-1-2
1-5-6-1
5-6-1-5
6-1-5-6

# %% [markdown]
# ![321490306_1388106355333260_5077567737934932529_n.png](data:image/png;base64,...)

# %%
G10 = (V10,E10)
V10 = {1,2,3,4,5,}
E10 = {(1,4),(2,1),(2,5),(3,1),(3,4),(4,1),(4,3),(4,5),(5,2)}

Indegree of:
node 1: v = (2,3,4) 
node 2: v = (5)
node 3: v = (4)
node 4: v = (3,1)
node 5: v = (2,4)

Outdegree of:
node 1: v = (4) 
node 2: v = (5,1)
node 3: v = (1,4)
node 4: v = (1,3,5)
node 5: v = (2)

Adjacent to:
node 1: v = (2,3,4) 
node 2: v = (5)
node 3: v = (4)
node 4: v = (3,1)
node 5: v = (2,4)

Adjacent from:
node 1: v = (4) 
node 2: v = (5,1)
node 3: v = (1,4)
node 4: v = (1,3,5)
node 5: v = (2)

Edges incident to:
node 1: v = {(1,4),(4,1),(3,1),(2,1)} 
node 2: v = {(2,1),(2,5),(5,2)}
node 3: v = {(3,4),(4,3),(3,1)}
node 4: v = {(1,4),(4,1),(3,4),(4,3),(4,5)}
node 5: v = {(5,2),(2,5),(4,5)}


Simple Paths:

1-4
1-4-3
1-4-5
1-4-5-2
2-1
2-1-4
2-1-4-3
2-1-4-5
3-1
3-1-4
3-1-4-5
3-1-4-5-2
4-1
4-3
4-3-1
4-5
4-5-2
4-5-2-1
5-2
5-2-1
5-2-1-4
5-2-1-4-3

Simple Cycles:

1-4-1
1-4-3-1
1-4-5-2-1
2-5-2
2-1-4-5-2
3-4-3
3-1-4-3
4-1-4
4-3-4
4-3-1-4
5-2-5
5-2-1-4-5
