# %% [markdown]
# <a href="https://colab.research.google.com/github/GeraldChristianBalindan/CPEN65-2/blob/main/Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
6.) Children of node 16?
      Nodes = 13, 6, 60

7.) Parent of node 1?
      Nodes = 7

8.) Siblings of node 23?
      Nodes =

9.) Ancestors of node 9?
      Nodes = 4, 12, 7, 22

10.) Descendants of node 16?
      Nodes = 13, 23, 6, 60, 21

11.) Leaves.
      Nodes = 23, 6, 21, 20, 9, 1

12.) Non Leaves.
      Nodes = 13, 16, 60, 12, 7, 22

13. Depth of node 4?
      Answer: 3

14.) Degree of the tree?
      Answer: 3

15.) Height of the tree?
      Answer: 4

16.) Weight of the tree?
      Answer: 6

17.) Is the tree a binary tree?
      Answer: No, since node 16 has a degree/no. of children of 3 

18.) Removing 6, is the tree a full binary tree?
      Answer: No, since nodes 13 and 60 only has one child or a degree of one

19.) Removing 6, is the tree a complete binary tree?
      Answer: No, since leaf node 1 has a depth of two while leaf nodes 23, 21 and 20 has a depth of 3 and lastly leaf node 9 has a depth of 4.
          Another reason is that non leaf nodes 13, 60 and 4 are in degree of one while the non leaf nodes 16, 12, 7 and 22 are in degree of two.

20.) Is a full binary tree complete?
      Answer: No, It is true that in full binary tree, all nodes has exactly 2 degrees which meets one of the requirement needed to be considered as a 
      complete k-ary tree but the leafs of a full binary tree can have different depths which doesnt meet the other requirement for a tree to be called a 
      complete k-ary tree which is all leaf nodes should always have the same depth.

21.) Is a complete binary tree full?
      Answer: Yes, A complete 2-ary tree should contains leaf nodes with same depth but more importantly, all of the non leaf nodes of a complete 2-ary has a degree 
      of two which is also the requirement needed by a tree to be considered a full binary tree.

22.) How many leaves does a complete n-ary tree of height h have?.
      Answer: By using the formula n^h you can find out how many leaves are in the specific tree
      Example: if the tree has a height of 4 and it is a complete 3-ary tree then

      n = 3 , h = 4
      By Substitution: 3^4 = 81
      The total number of leaf nodes on the tree is 81

23.) What is the height of a complete n-ary tree with m leaves?.
      Answer: By using the formula log base of n (m) you can find out the height of the tree
      Example: if the tree has 81 leaves and it is a complete 3-ary tree then

      n = 3 , m = 81
      By Substitution: log base of 3 (81)
      The heigt of tree is 4


24.) What is the number of internal nodes of a complete n-ary tree of height h?.
      Answer: By using the formula (n^h-1)/(n-1) you can find out the number of internal nodes of the tree
      Example: if the tree has a height of 4 and it is a complete 3-ary tree then

      h = 4 , n = 3
      By Substitution: (3^4-1)/(3-1)
      The number of internal nodes in the tree is 40


25.) What is the total number of nodes a complete n-ary tree of h have?
      Answer: By using the formula (n^(h+1)-1)/(n-1) you can find out the number of nodes in the tree
      Example: if the tree has a height of 4 and it is a complete 3-ary tree then

      h = 4 , n = 3
      By Substitution: (3^(4+1)-1)/(3-1)
      The number of existing nodes in the tree is 121

      Alt solution:
      no. of leaves + no. of non leaf nodes
      (n^h) + (n^h-1)/(n-1)
      (3^4) + (3^4-1)/(3-1)
      81 + 40 
      121 = no of nodes in the tree
